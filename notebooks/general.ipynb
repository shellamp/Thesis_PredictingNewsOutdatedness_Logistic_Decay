# %% [markdown]
# Summary Count of each Label

# %%
import json
from pathlib import Path

INPUT_PATH = Path("/Users/sheillaschool/Documents/final/Thesis_PredictingNewsOutdatedness_Logistic_Decay/model/probability_model/labelled_dataset.json")

def load_json(file_path: Path) -> dict:
    """Load JSON file and return as dict."""
    with open(file_path, "r", encoding="utf-8") as f:
        return json.load(f)

def summarize_labels(data: dict) -> dict:
    """Count labels 0, 1, and None in dataset."""
    total = len(data)
    count_0 = sum(1 for v in data.values() if v.get("label") == 0)
    count_1 = sum(1 for v in data.values() if v.get("label") == 1)
    count_none = sum(1 for v in data.values() if v.get("label") not in [0, 1])
    return {
        "total": total,
        "label_0": count_0,
        "label_1": count_1,
        "label_none": count_none
    }

def print_summary(summary: dict) -> None:
    """Nicely print the label summary."""
    print("📊 === Label Summary ===")
    print(f"Total articles: {summary['total']}")
    print(f"Label 0: {summary['label_0']}")
    print(f"Label 1: {summary['label_1']}")
    print(f"No label: {summary['label_none']}")

if __name__ == "__main__":
    data = load_json(INPUT_PATH)
    summary = summarize_labels(data)
    print_summary(summary)
# Out:
# 📊 === Label Summary ===
# Total articles: 11359
# Label 0: 11012
# Label 1: 347
# No label: 0

# %% [markdown]
# JSON to XLS

# %%
import json
import pandas as pd
from pathlib import Path

JSON_PATH = Path("/Users/sheillaschool/Documents/final/Thesis_PredictingNewsOutdatedness_Logistic_Decay/model/labelling/data/manual/manual_review_sample.json")
EXCEL_PATH = JSON_PATH.with_suffix(".xlsx")

def load_json(file_path: Path) -> dict | list:
    """Load JSON file and return as dict or list."""
    with open(file_path, "r", encoding="utf-8") as f:
        return json.load(f)

def json_to_dataframe(data: dict | list) -> pd.DataFrame:
    """Convert JSON data to DataFrame, auto-detecting format."""
    if isinstance(data, list):
        print("🔍 Detected format: records (list of dicts)")
        return pd.DataFrame(data)
    elif isinstance(data, dict):
        print("🔍 Detected format: index (dict of dicts)")
        df = pd.DataFrame.from_dict(data, orient="index").reset_index()
        df = df.rename(columns={"index": "article_id"})
        return df
    else:
        raise ValueError("Unsupported JSON structure. Must be list or dict.")

def save_dataframe_to_excel(df: pd.DataFrame, file_path: Path) -> None:
    """Save DataFrame to Excel."""
    df.to_excel(file_path, index=False)
    print(f"✅ Excel saved to: {file_path}")

def save_dataframe_to_json(df: pd.DataFrame, file_path: Path) -> None:
    """Optionally save DataFrame back to JSON if needed."""
    data = df.to_dict(orient="records")
    with open(file_path, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    print(f"✅ JSON saved to: {file_path}")

if __name__ == "__main__":
    data = load_json(JSON_PATH)
    df = json_to_dataframe(data)
    save_dataframe_to_excel(df, EXCEL_PATH)
    # Optional: save the same DataFrame back to JSON (records format)
    # save_dataframe_to_json(df, JSON_PATH.with_stem(JSON_PATH.stem + "_records"))
# Out:
# 🔍 Detected format: index (dict of dicts)
# ✅ Excel saved to: /Users/sheillaschool/Documents/final/Thesis_PredictingNewsOutdatedness_Logistic_Decay/model/labelling/data/manual/manual_review_sample.xlsx

# %% [markdown]
# XLS to JSOn

# %%
import pandas as pd
import json
from pathlib import Path

# === CONFIG ===
EXCEL_PATH = Path("/Users/sheillaschool/Documents/final/Thesis_PredictingNewsOutdatedness_Logistic_Decay/model/labelling/data/manual/manual_review_sample_filled.xlsx")
JSON_OUTPUT_PATH = EXCEL_PATH.with_suffix(".json")

def load_excel(file_path: Path) -> pd.DataFrame:
    """Load Excel file to DataFrame."""
    return pd.read_excel(file_path)

def dataframe_to_indexed_dict(df: pd.DataFrame, index_col: str = "article_id") -> dict:
    """Convert DataFrame to dict-of-dicts with specified index column."""
    if index_col not in df.columns:
        raise ValueError(f"Column '{index_col}' not found in DataFrame columns: {df.columns.tolist()}")
    df = df.set_index(index_col)
    return df.to_dict(orient="index")

def save_json(data: dict, file_path: Path) -> None:
    """Save dict to JSON."""
    with open(file_path, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    print(f"✅ JSON restored and saved to: {file_path}")

def main():
    df = load_excel(EXCEL_PATH)
    restored = dataframe_to_indexed_dict(df, index_col="article_id")
    save_json(restored, JSON_OUTPUT_PATH)

    print(f"🔑 Total articles: {len(restored)}")
    print(f"📄 Fields in each article: {df.columns.tolist()}")

if __name__ == "__main__":
    main()
# Out:
# ✅ JSON restored and saved to: /Users/sheillaschool/Documents/final/Thesis_PredictingNewsOutdatedness_Logistic_Decay/model/labelling/data/manual/manual_review_sample_filled.json
# 🔑 Total articles: 120
# 📄 Fields in each article: ['article_id', 'source', 'url', 'date', 'title', 'body', 'summary', 'category', 'title_normalized', 'summary_normalized', 't', 't_bin', 'label', 'label_comment', 'reviewed_label']

# %% [markdown]
# Adding article id

# %%
import json


input_path = "/Users/sheillaschool/Documents/final/Thesis_PredictingNewsOutdatedness_LogisticDecay/data/main_data/main_data.json"
output_path = "/Users/sheillaschool/Documents/final/Thesis_PredictingNewsOutdatedness_LogisticDecay/data/main_data/main_data.json"


with open(input_path, "r", encoding="utf-8") as f:
    data = json.load(f)


new_data = {}
for idx, (url_key, article) in enumerate(data.items()):
    new_data[str(idx)] = article 


with open(output_path, "w", encoding="utf-8") as f:
    json.dump(new_data, f, ensure_ascii=False, indent=2)

print(f"✅ Done. Saved {len(new_data)} articles to '{output_path}'.")
# Out:
# ✅ Done. Saved 29734 articles to '/Users/sheillaschool/Documents/final/Thesis_PredictingNewsOutdatedness_LogisticDecay/data/main_data/main_data.json'.

# %%
import os

def print_tree(startpath, indent='  '):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        prefix = indent * level + '├─ '
        print(f'{prefix}{os.path.basename(root)}/')
        subindent = indent * (level + 1)
        for f in files:
            print(f'{subindent}├─ {f}')

# Example: replace with the folder you want
print_tree("/Users/sheillaschool/Documents/final/Thesis_PredictingNewsOutdatedness_Logistic_Decay")
# Out:
# ├─ Thesis_PredictingNewsOutdatedness_Logistic_Decay/
#   ├─ .DS_Store
#   ├─ requirements.txt
#   ├─ wandb-api-key.txt
#   ├─ README.md
#   ├─ .gitignore
#   ├─ .gitattributes
#   ├─ models/
#     ├─ .DS_Store
#     ├─ annotation/
#       ├─ .DS_Store
#       ├─ docs/
#         ├─ confusion_matrix.csv
#         ├─ validation_metrics.csv
#       ├─ scripts/
#         ├─ rule_based/
#           ├─ rule_based.py
#           ├─ review.py
#           ├─ validation.py
#         ├─ manual/
#           ├─ validation.ipynb
#       ├─ data/
#         ├─ .DS_Store
#         ├─ rulebased/
#           ├─ rulebased_labelled.xlsx
#           ├─ rulebased_review.json
#           ├─ rulebased.json
#           ├─ rulebased.xlsx
#           ├─ rulebased_review.xlsx
#           ├─ rulebased_labelled.json
#         ├─ manual/
#           ├─ manual_review_sample_filled.xlsx
#           ├─ rulebased_manual.xlsx
#           ├─ manual_review_sample.json
#           ├─ manual_review_sample.xlsx
#           ├─ rulebased_manual.json
#           ├─ manual_review_sample_filled.json
#     ├─ finetune/
#       ├─ .DS_Store
#       ├─ data/
#         ├─ remaining_majority_not_in_seed.json
#         ├─ predict_ready.xlsx
#         ├─ train_balanced.json
#         ├─ val_balanced.json
#         ├─ test_balanced.json
#         ├─ train_balanced_plus_bt_separated.json
#         ├─ train_remainder.json
#         ├─ predict_ready.json
#         ├─ train_balanced_plus_bt.json
#         ├─ train_ready_balanced.json
#       ├─ notebooks/
#         ├─ merge.ipynb
#         ├─ dataaugment.ipynb
#     ├─ probability_model/
#       ├─ labelled_besthparam_dataset.json
#   ├─ docs/
#     ├─ .DS_Store
#     ├─ Presentation_thesis_thingy.pptx
#     ├─ Thesis_PredictingOutdatedness_Logistic_Decay.docx
#     ├─ Thesis - Log AI.xlsx
#   ├─ .git/
#     ├─ ORIG_HEAD
#     ├─ config
#     ├─ HEAD
#     ├─ description
#     ├─ index
#     ├─ .MERGE_MSG.swp
#     ├─ packed-refs
#     ├─ COMMIT_EDITMSG
#     ├─ FETCH_HEAD
#     ├─ objects/
#       ├─ 61/
#         ├─ e4c98763f9c105c5cf6b9bf952de883094207a
#         ├─ 7b8c59f193c3b021948ef3e84853c360f918e6
#         ├─ 5c74e270f46ea79816f4c2e9ba9f393b8514d0
#       ├─ 0d/
#         ├─ 61111fd9c3aaa63be45d5a4b77de521ca79fb9
#       ├─ 59/
#         ├─ d0a9d6d4beb1df8af572c3644745d6a4fa8a8c
#       ├─ 92/
#         ├─ 08bb6bd0bfdbcb1c06d17ceffecf14a0f847df
#         ├─ fd0e1af8b7d5338bf5c2c5f1730691b83d2c2d
#         ├─ 351b49f9cc4f80899e1b7ad046c30be5ec7d9b
#       ├─ 0c/
#         ├─ 9c7ae41eb298316e87fa7d24dc5f765bef89cf
#       ├─ 66/
#         ├─ d622947e7b8476d2c66d7f4521fa6afecb1a00
#         ├─ 71e153d4bf41674423e2da9833d9eaa5e515ef
#       ├─ 3e/
#         ├─ 61c8a2b2df31029412cdb8ae14ff7bc73a9ff5
#       ├─ 50/
#         ├─ 08ddfcf53c02e82d7eee2e57c38e5672ef89f6
#       ├─ 68/
#         ├─ 586da00124b12933dffab2131c028d80d8be1e
#       ├─ 57/
#         ├─ cfdd76ef41a6aec015743db5de6824adfb65fc
#       ├─ 3b/
#         ├─ 3b2c36c9b0be802d4822a61aa7e1111c26c765
#       ├─ 6f/
#         ├─ 7fc76929a22de702cba149577632c02d20e9a8
#         ├─ 0adff053bc5807525f20e16e4fc1dee3381389
#         ├─ e95be80b1bd6799e237db99fef105bb8c39dd4
#       ├─ 03/
#         ├─ c925025a144d7b522ed5900fa06b9d562ec263
#         ├─ 399dd8a701891045ccea6c442f0c791e6211fc
#       ├─ 9e/
#         ├─ 4e481446b1c55c473df9d46cc8484933b017bc
#         ├─ 529d40869e9672bc262f14ed0e9ae657e7410c
#         ├─ 30cb16cbae15e4e06940cdafe64ff003cfba47
#         ├─ 4b915fde56a75414087f9e8e3c9cc4258052ec
#         ├─ c8364b30b13c2f578e123f6e9a4b4ace71e70b
#       ├─ 6a/
#         ├─ f711e816434d6aef949bab6d31d2171d1f72c3
#         ├─ 26b325b57dd9edaa8fe9a6d84cde10db40073f
#         ├─ 32b9ff5b21674bde13d433ff81efaae2dae9cc
#         ├─ 3c753793f6c026ec30bc66b63f067667def311
#       ├─ 32/
#         ├─ 2d16d60bffd1382ac75d48e4b85aea482fa96e
#         ├─ f6029b50e561179f827ad8fe0392b24fbf481c
#       ├─ 35/
#         ├─ d437a6f73f2b3a4150e74675c7af4f21df47d9
#         ├─ 2d2cf486835e8251d5474ac186201a43667cf9
#         ├─ 1ebe37df5a958c4b72c53c42aa16c9c1c12011
#       ├─ 69/
#         ├─ 52ebd6504b1e5d57989879b3c09af0dc1663ae
#       ├─ 3c/
#         ├─ 7fa11589610711e78883e0404ccf1a971c61e6
#         ├─ ba2b23f052d74f6d1b2782fa1e0c4560fe8adc
#       ├─ 56/
#         ├─ 536ea9caf5b8394340097258819fbda239eb84
#       ├─ 51/
#         ├─ a72a831ef56419b708401ea2143d6f16528166
#         ├─ d12ee70b745effe89e54faec5cb6f05296517a
#       ├─ 3d/
#         ├─ abb8106cd8539aa2d70918516e22ed352b3ac1
#       ├─ 58/
#         ├─ cd91da930685792ece5b559ec1589904933526
#         ├─ 26e30b2523555e5194183833998ec8a256e11c
#       ├─ 0b/
#         ├─ 26109e0f8dc2f5fb31d9e801c0d58e70893c4b
#         ├─ e346e6fb1158878ef318bead793500e8a3e638
#       ├─ 93/
#         ├─ 86be94a7e8f5ce85cbc40dc715b84c72ff4a2d
#       ├─ 94/
#         ├─ 6791c4d2716576c084a192612378d8f1ecda07
#         ├─ 4268af3bc9ee3325862135530ce8b599f4fa0c
#       ├─ 0e/
#         ├─ 53b0b2ac7dc0f86761f7b2438b74efb5e4316f
#       ├─ 34/
#         ├─ 55a81d090fee073acb1ecc20d3399ec7c09290
#       ├─ 5a/
#         ├─ 0e0ef629548c1b6e1ef1d0201f37fc17550c4a
#         ├─ 311354902d15f53e0dc9c8ba538d404f59fc78
#         ├─ 05288662d3301b0e11e599bccfa0602414c595
#       ├─ 5f/
#         ├─ b304492bf476a9e5b7d3ae65cf413a6c2208a2
#         ├─ b15fcb5726d8f760677044cea23b7ecd53ff1e
#       ├─ 33/
#         ├─ 74f67507cdbd55d9a455f9335690e3c04eabd5
#       ├─ 9d/
#         ├─ df62faeef4eef091fab38f71d20a1a0294d5e4
#         ├─ 5794434a0284e681954277b855a90bc4b44e1f
#       ├─ 9c/
#         ├─ 0f623e66dc70763fdc2119b0763b567e93bbe4
#         ├─ 0e86a2defe4da88c55d1aae20fc36e04bd0c29
#         ├─ a57ba7a92efcacfb70fcd2cec4e94467722aba
#         ├─ 7f9010a792c3e0ed9f6b364a3a05dc51813480
#       ├─ 02/
#         ├─ d3da404dc6840334fe8572b7570a2b3669a76c
#         ├─ 700bb0af0b47d5379017b2aecd8af2b07050e8
#       ├─ a4/
#         ├─ c19d723c0fe80f8a7dbcc6e11bbad40808aee7
#         ├─ 589876d890ef696cbce5c4d8e421dabb3671cf
#         ├─ 4021966a8a98134a78ee1a2f1a0b8e5d9990e0
#       ├─ a3/
#         ├─ 5275c163b80b2ca5d37a8c9a4ddd30ae4aa9bc
#         ├─ 2f068895d75c9b6fdcc0ae8199550f983e8b18
#       ├─ b2/
#         ├─ 6a96ce4cbb78430bd297d392e45b210db8cd32
#         ├─ c1d71b2f8682c614a4bbefc6dd5650fd2918ce
#       ├─ d9/
#         ├─ 241ecf4b6b09cb2ae3bbdb9e469d1d2c92c283
#         ├─ 13c886952295c7adf9e6632f4ac086c01f9921
#       ├─ ad/
#         ├─ 9e19ebcd29a8b2d5a6d04396511f03678243c0
#       ├─ d0/
#         ├─ af464dbcc82df8dbfe10091e52016ba7955bfe
#       ├─ be/
#         ├─ 5ed6dc4ef013eb2cb9d4627b194b7c544d0746
#         ├─ 5e9fb60fc12391652058654a56849fcbad4788
#         ├─ 8b3e2d6958328c3b31bc791ac83c645a2b6ed8
#         ├─ 63daf29e9f7221a02ba85a0f45b708a6b80021
#       ├─ b3/
#         ├─ 8865706e0753de4ed194f260c47d9c792b952b
#         ├─ c703e8e91ef0e7526cf2813123062752b5b20a
#       ├─ df/
#         ├─ 899a5708ab707ede129254573ea3645b4463cd
#         ├─ 90bac786eab60f26f25febea2169657e14b1da
#       ├─ da/
#         ├─ a661ac0d3e8181d67d75ce31d69f7baaf5260c
#         ├─ bdc5cf0a86c2c1f90ef21312c5f68dd357ae37
#       ├─ b4/
#         ├─ 39bbd81a7ec0944053321aba5be91204d0ed56
#         ├─ a6df7112b999bb7602c78bbe4c3f1250124588
#       ├─ a2/
#         ├─ cde808b2cc70de925b51e027479b21e50adf1e
#         ├─ c874893b2f6c7be5083bea5d67f737a66c751e
#         ├─ df35a8155d231050c59b65bacae9745b059816
#       ├─ a5/
#         ├─ fbd87f65dee9ccde328a4e1afd50026c9caa34
#       ├─ bd/
#         ├─ 127401aef955dad2f057413562f557d7eb1591
#         ├─ 53e6c420360902088be83493db8fbf14a64d59
#       ├─ bc/
#         ├─ 5adfee86cc9fa4bffc93edc4fbe4fef285943f
#       ├─ ae/
#         ├─ aa223d50b0f4fbaf28f34c2f357f25d9fc4f26
#       ├─ d8/
#         ├─ 5667893bb11302f1b11f60008cf5c3a8fbde14
#         ├─ 0d80aa8349bd49bcdcf2e4541459b1ade5d3ef
#       ├─ ab/
#         ├─ a2fdbe01650cc4eceae54a8b5279c112660e36
#       ├─ e5/
#         ├─ 6db85f20025bd3fdb8c53e6d6b45d74e435a58
#         ├─ 98a81452c3bbef1e80966721e6a8a080e49a97
#       ├─ e2/
#         ├─ f7a3d1f325ce5862c6fd94c04c730b17193621
#         ├─ 198b2e5d8022791b59209f388d72b65083030e
#       ├─ f4/
#         ├─ 6f6fda4498f3e35ed6e4c317216609cbaa3243
#       ├─ f3/
#         ├─ 91505d5609e9946563b0ec7384f7e430751175
#         ├─ 86b0d7d0e938bdbf3ef3d8883a505c90e8aac3
#       ├─ c7/
#         ├─ 9fcdb3ec28dc9c7be9cb7582aa6d9d9e9a11ed
#       ├─ c0/
#         ├─ ee4380340c6cf63f2c5599d3e32ed0b21bb9fe
#       ├─ ee/
#         ├─ cf4c570466667169e6ccb2cb33ce593eb3ca1f
#         ├─ 2e65668ad843b197abd38a7f8e3dedabe908a8
#       ├─ c9/
#         ├─ b7558dab30f7b007cbe191d918e0178b71f6ba
#       ├─ fc/
#         ├─ 2d289bc2b8ef3fa041219e0e9e82b369fa2cc8
#       ├─ f2/
#         ├─ 086c8b8d0dadfe57f4deb6e9ec3c453a95f658
#       ├─ f5/
#         ├─ 5d98645d1b0a44736454e8338d4c8c271ab45e
#       ├─ e3/
#         ├─ 10a6633066ee61611c384ac68e5d3838b0cad8
#         ├─ 6423d3b2b12e0e3e0cf0f7417fa1b72abae39b
#       ├─ cf/
#         ├─ 70235f78b40d743b128f74e0259402f4d343e2
#       ├─ ca/
#         ├─ 696236ad93dc9586ffc13ef547e3bdeef9f0f6
#       ├─ e4/
#         ├─ 4f1ccdd4dc043b0b2d364fc30cd021b2493b74
#         ├─ 54868d558fdc07a30c7208cff241aab1e2b76f
#       ├─ fe/
#         ├─ 4bec4fd1132927ab1ebb926fd439454d2e9ad1
#       ├─ fb/
#         ├─ 4f3b220ae46e316922444d8a0c408e7901bf53
#         ├─ 7c62a9e07be9d10a7b7c749bd44f640eef6cf3
#       ├─ ed/
#         ├─ 274c093cf0f6a308e1bacfccf338994f0bd0bc
#         ├─ 6f42096feefea0bd4decb74563c063c83e3805
#       ├─ c1/
#         ├─ 4f90a266b4290952af4d69ff033a14514b2675
#         ├─ d0e3467d486f64f64735368052c91a3390d50d
#         ├─ 9d5567a9077096c67d5be04f79efeec6d6b9e7
#       ├─ c6/
#         ├─ 0144c2e5da77fd6207168919e5fa1f9d85f627
#         ├─ 11f907c46a9353f814659f372a467255d3df4e
#       ├─ 20/
#         ├─ 92a4d1cbee78ff9440d4fd5e37c5fc9a0e0871
#       ├─ 18/
#         ├─ 981fc7d5fe72f8c0de6aad00fb6c6f934d2217
#       ├─ 27/
#         ├─ cffd46cb39d06bb8e42c4a2275de8609b8a526
#         ├─ 0dbe7e5ab87b447151f5b7154fd94f8eb0cc54
#       ├─ 4b/
#         ├─ 961a6c8116bd33b049cbfc11aadb2782883509
#       ├─ pack/
#         ├─ pack-3599d9fa7492c1b37d559eca4389d041b6edd729.pack
#         ├─ pack-3599d9fa7492c1b37d559eca4389d041b6edd729.idx
#       ├─ 11/
#         ├─ ad318fee329f7204090359e0ce2315ffacd507
#         ├─ 66c8f479495aed1c706bf5a12b4db077b29557
#       ├─ 7d/
#         ├─ 32777a7a6273546267ef357deb62064e39421e
#       ├─ 29/
#         ├─ 4a8f9a63bb4e79c9a8d10b7682263b56acc844
#       ├─ 7c/
#         ├─ 6031f53621d383590c95cdd29790a833e4f87a
#       ├─ 16/
#         ├─ 9f8b832d8ecf10ca3c46a3f58b1b9c9c6fe086
#       ├─ 42/
#         ├─ fa19385dc18361bfbe181d69e8ab159e37440b
#       ├─ 89/
#         ├─ 56bb0952ce6735ceae28fa926998b6eebc446a
#         ├─ 0fe91ffa5095503474b189e6b19f17f81b801c
#         ├─ a7c8ea1436b6931e2a942375a1130b3f5ca1d3
#         ├─ 5b3be37aed34f5a3a19d434cd53ec99cb9321c
#       ├─ 45/
#         ├─ b37465f52574a1ec74f1573fdc31a21ff4506f
#         ├─ 13eacd525ab0f5a64d5299f2209165733c9548
#       ├─ 1f/
#         ├─ 4b05e9435ddcc30fcb76ab128a22106a946c5e
#       ├─ 73/
#         ├─ 4e33982ec79e107518a2bd974b5ddb076f9b3e
#       ├─ 87/
#         ├─ 9b4c9fee9da7f0fb5bfc30d27cbf432cf84bb4
#         ├─ 0cf325f4e6401d9742452d2b0fca3950d36464
#         ├─ 1c1810b93b435d23bde6af9f576b1f194d85e3
#         ├─ 249a967d49be157753c443def9621dd8250bb9
#       ├─ 80/
#         ├─ b103795ae7d1b096eee81938067afd5236efee
#       ├─ 74/
#         ├─ d85d14644ffd62cb1d713b65de4dc1685b2f4c
#       ├─ 1a/
#         ├─ 63d7dc417bdbe5ebc585412578e5141674373e
#         ├─ 8d9bb9258ac4743da06e9e49606a4cb684cf9b
#       ├─ 28/
#         ├─ ed4ccd2fb59f71e377f98dc629ff3351cac933
#         ├─ e0eefa9819722935d47a673e654e341a551698
#         ├─ f1795df5f5580a097db8c29e127a46c3a4774b
#       ├─ 7b/
#         ├─ ea504bcab2803873f4aaca0c5cb47e20d876e5
#         ├─ 0bc0b075ee3924ce874448527bc4ab24c8fcd7
#         ├─ 9d33741ed04ce8ac5299ff580d34195ae35713
#       ├─ 8a/
#         ├─ c489971cc70cd52a4d64a71917eddc58917381
#       ├─ 7e/
#         ├─ 7ff58aca69fbecead0ba1dc35143f953eea1bc
#       ├─ 10/
#         ├─ 18c522a6f1941d4b62b2d8a371aad31e9124b6
#         ├─ 83bf5945e82c7dbbadfc6178324649a7d110d9
#       ├─ 19/
#         ├─ 1b26432355ce07b7304a952e8a40f439a1a046
#       ├─ 4c/
#         ├─ d29d097bf205cc17ad827e945ce5ce8d827474
#         ├─ f7cb658d2e85a01b5c4f1130224149cc72ee1f
#       ├─ 26/
#         ├─ 63bba5ca34c193f9b51cf0171e3f08446bc649
#       ├─ 4d/
#         ├─ be9d397c8ba7b2f4048ea61e580018a757360e
#         ├─ e4815af43e98250c07bd976e2f138064ec98ed
#         ├─ 85597c5982b9901b513edffd97cc9e53d5a10e
#       ├─ 75/
#         ├─ e7425ada87e1b3751a37191aa9ec8c156a3cf2
#       ├─ 81/
#         ├─ 2703c42bbca47924b5c5033d4019c507805220
#         ├─ d6e82e08e1c6fc19ee5ae3601769c9ee1accca
#       ├─ 86/
#         ├─ 788578b56c0740b879fc4b48635f22da374b3d
#         ├─ b6e084a7164a4515affd9a476ae17f8e956a64
#         ├─ ea02f6606a3f2c5f9b112db86e8036eece0022
#         ├─ 2a2559b52c33d42eb0f7d8547a120e8890f2dd
#       ├─ 72/
#         ├─ 053cfc11dc6d9a931ad80e6464f2ab6396359f
#       ├─ 44/
#         ├─ 8e3b544ad1e0f6ab7b7898ee118370f6b14d8e
#       ├─ 2a/
#         ├─ adbd4095aad074f9c8f4ddb0b762c1c8d28da7
#         ├─ 3948c55000b9e5dbef203854afb8bd150969d7
#       ├─ 2f/
#         ├─ 318a03c8b433839d682b2fcae0015844794345
#         ├─ 9eef01de118596cb5e807123874280aa1e0643
#         ├─ b0461522dc0e7a566c0bbf45729c78ae0d619e
#       ├─ 88/
#         ├─ aa19524d28228a91c6d25213f6132de975fc22
#         ├─ 2b5eae6e0a532af1ae20dc0d36d4c45d7719ed
#       ├─ 9f/
#         ├─ 0ffb44764365eac9ab6a5035213c496f83b015
#         ├─ 931522ad3e4c87c0901ee7add54fd6f4f8b061
#         ├─ 35525e06725f609d5b6053399a9d6621e16e6f
#       ├─ 07/
#         ├─ 06d810f32e521f19aedbcd4d2fbbfd82a0aecd
#       ├─ 38/
#         ├─ 583a9385ee608cd851522d48434bd010b562d4
#       ├─ 00/
#         ├─ e6e25526511465eef997042731b3dad97eec3c
#       ├─ 9a/
#         ├─ c20e9ea91e52d835d579fedd8a31c3143a5724
#       ├─ 36/
#         ├─ 396ba7b47c8ea7eceebab9a785c5b5815a06c6
#         ├─ 1ae35c6164e41480ad05be602eff309a201b5e
#         ├─ 9a277d68932ce890fcbf21dcaf976c8163a7ad
#       ├─ 5c/
#         ├─ 5fe5530e1352fbfbc8aaacd84f01b37702d85c
#         ├─ 33b19aa05dace6f5ffb6df40766c3e35af3f1f
#       ├─ 09/
#         ├─ 9a05a7232dc53a2e520b4567b86d1c55438a38
#         ├─ c9ebd74355840cbf0bb023b8045e0991c7aed8
#         ├─ 1c962a03a46743836a6b68f3d59a46d3c446d9
#       ├─ 31/
#         ├─ b017e80a68224173843f43f14ace2e8940daf5
#         ├─ 63bbb151271975af0f69ab5a4b9dc4bc176400
#         ├─ 3c0f10892fa6730a0019b92a6624bf4dfc0b5f
#         ├─ e957898db0370e57714d29abc489ecdab8647d
#       ├─ info/
#       ├─ 65/
#         ├─ 57077b5a3ba8afe9bfd97c6461077c0088413c
#         ├─ 16d1e2d5ebd1452913218e44301a292009f216
#       ├─ 62/
#         ├─ 8657d1a9c69676bcd713fa0e7cab29452013ec
#         ├─ 93c415e25170b6e2ec8dc62493746f524f9898
#         ├─ f851fba59ce2f805ac0a62d3c495621ab0302c
#       ├─ 3a/
#         ├─ 6cc01c1028e1a431a932f5a9ba8db6ae98ca9e
#         ├─ 95544089eda061a2dabdcbd009d02be54d2770
#       ├─ 54/
#         ├─ 9a7d2e8996a84888902d9ba709fb18a639c871
#         ├─ 373d48c4efe45923c9702815ae4a548e69fe4b
#       ├─ 98/
#         ├─ 283b6ec42c9996f5e2918dab1b9cbd09b6f15a
#       ├─ 53/
#         ├─ a9830cd40a313fd4d5a65469816a3df49ed57d
#       ├─ 5e/
#         ├─ 21f16709022c873c673a3e7358fcdbef9f83cb
#         ├─ 438fa1b34eeb93b821b34cc08e9ffbc8b3e476
#       ├─ 5b/
#         ├─ bbbb5734c54dd6bde09abfae3f5e43147e5ce2
#         ├─ e697f6bdf576b63656f1576671df526ad9f8b5
#       ├─ 37/
#         ├─ 5ff35d16e1d42aa8772b3a14d933ae58477939
#         ├─ 5abc7326157e1e252c0ebbea677ee39b13c78a
#         ├─ 27dd0b4dc7c55f0b3c45e856f103879e0a19f3
#       ├─ 08/
#         ├─ 63f4a53c0c799e33e723470f0f49434a8917f2
#       ├─ 6d/
#         ├─ c9b948dff4a0b0ac1099bbfd73b001e607b1df
#         ├─ 2858beffc9139200741270313bc629ad7a866a
#         ├─ f8b32deddd9fcb0b601d8fdc4bcc45c5c5d242
#       ├─ 01/
#         ├─ cb9b63948eeffabdfd7fbda2f67365d295ff8f
#         ├─ ff201cb9b4cea4ff94810ebcf71d4989e1d599
#       ├─ 39/
#         ├─ dc7e721a11250de8b6ea66f72fdb317f4c3613
#       ├─ 52/
#         ├─ efba74df507aab3d99314a0e15ac9adce1972c
#       ├─ 55/
#         ├─ 50c32be16a5d008a838cbc852af46f1555339c
#         ├─ 88e8e72269c7442ee51ac95072c957c358197a
#       ├─ 97/
#         ├─ cf2f49682393efb96dd55c6c091e12e335b48e
#       ├─ 63/
#         ├─ 3f39c426047584a922835ae3f11651ac29ed2a
#       ├─ 0f/
#         ├─ fa274a64c032ac9a05aa6c1e65f5b3f598f3f4
#         ├─ e79f6252cf036e1f64bb70be715bc219c0c84a
#         ├─ 91eab025b5e3c5e02d9d4d2c34a28b5af12d9c
#         ├─ 34a114a8fad3942b3dc40129865b933d8d5346
#         ├─ ac1f419e7f205d835d61b20453b42615a8eadc
#       ├─ 64/
#         ├─ 9f2e2699d0b49b096a9ad3180a0088f3a25d19
#       ├─ 90/
#         ├─ 59870ea5982dc19cd85d47946668c344ccb2dc
#       ├─ d4/
#         ├─ 64500c87e8af634ce40c899a2fb34bc65a6a5d
#         ├─ 7c1039e89a1ba793a238b5a9b1df31338e8d0e
#         ├─ 369cd49f9c993bb4877191400218fdedd4ce16
#       ├─ a0/
#         ├─ 799e112303bc2dfa1c3b1b9cf490b85be8539c
#       ├─ a7/
#         ├─ c71088afa33155841052177a904126b7d41d4a
#         ├─ b4daab739df706cdbf1c82c08bdd7444273ba4
#       ├─ b8/
#         ├─ 9b586e36ce1f822ed024ff424d7716d59b7d03
#         ├─ f5ca528aae63ec566d1ce92d68156dfb871ed7
#         ├─ c7a046451dd0a88cc3c2ad12850e3c345aca73
#         ├─ 94e47c79d4b41bb5ad3e6fe98cc49eec983a25
#       ├─ b1/
#         ├─ eccb22c9f2726e8eab53f6610e1383c55f985f
#         ├─ aca55823c4132f05dff1e6c05cde0bf2fb92af
#         ├─ 82e02b0e91de9753cf5ca93b4ef986ebc498f0
#       ├─ dd/
#         ├─ b943d9b69552bacd4a7a40ac82ed088c0a7136
#       ├─ dc/
#         ├─ 5dbf97993fa90434e95f7737cc602d0af0cc8c
#         ├─ fbf76a89934aa5bbaee5a1031af4b9fdff7cfc
#       ├─ b6/
#         ├─ 2dc96e510961993d07e978965a5296c66ed467
#       ├─ a9/
#         ├─ 7e1faf0475ae3b7f373db1410797b85e5af9fa
#         ├─ cadf3a250d6900a23ee2a2d02fe9770c898728
#       ├─ d5/
#         ├─ 29717f6b6cde0519f3fb6e08a50aba0b233764
#         ├─ b4926d12d350c76988bf4cb1152e4832a7fe0d
#         ├─ 8ae12c25c4ed3ba3bcc8ba57f799de466d0a31
#         ├─ b490a2edb6426542c5524d1c829deba7004dca
#         ├─ 9e1c554bcf5e5f696c573166b55660a468f344
#       ├─ d2/
#         ├─ 531d5f3e332af6bc4d18ce3e0eb656a5fdc4d2
#         ├─ af0679b144257f151462932ea75a5b8ee866aa
#       ├─ aa/
#         ├─ 7bb9d964100d814a8ddbf37e20edd3bde12780
#         ├─ 53a1bb4c6ad6b7b8f95ea9e1dd9c5276ca82e3
#       ├─ af/
#         ├─ ddf41754e0e71e6cd81a1bd53913c45728d163
#         ├─ 051f85da81a168b7f3351c68dc005a16062dff
#       ├─ b7/
#         ├─ c9c64fcdc8f405279be726eaa2d94fbea6627c
#         ├─ 8ea20655c37856c47da91d7a9511fb23a5514c
#       ├─ db/
#         ├─ 555992a9a6e8e52efde021505be966176d7ef3
#         ├─ 643351e613fefdf00b31583fd2dacdb82ea13c
#       ├─ a8/
#         ├─ 81e87d654602b741621387c8720447bb32ac8d
#         ├─ aa25873789a2ceb891fcbb4b2df463e06bc056
#         ├─ f44c24da4c8aecc9f9dd7dedcdb021b5cd89fd
#       ├─ de/
#         ├─ 49935fc5a54b973f25caae5aa977f905c91edb
#         ├─ 12c0453754225d8c9fa13113a26581e2bc0fc4
#       ├─ b0/
#         ├─ ca234ef8c27a55693e731a479dc5d7b7bf120e
#         ├─ 926b75a4929bfa7bf4af7a00ea430db6810221
#       ├─ b9/
#         ├─ 7f75d7aa71db9abf0cc460fdb94456d9b597f5
#         ├─ bbd69d1227ae8c0a34fe8acaed5530b298c8b4
#       ├─ a1/
#         ├─ 37c32a7be80ac375073f9ee495c027fe5562de
#         ├─ 5a04e92900dfba26d549b1e7adb8770b1f3e5b
#       ├─ ef/
#         ├─ 51d4aed064168e4fa00d4ef73f11a2280b53fb
#       ├─ c3/
#         ├─ 84196943db9421d9d40972ecfadb907c3c9c2e
#       ├─ c4/
#         ├─ 1caec58ee5d19fad1ff26cb5a8b3fded957733
#       ├─ ea/
#         ├─ 0076932254302aa5a61cae99621e45bb309675
#         ├─ 07d8879d66c15f71c9690247d9d28299b4cf9d
#       ├─ e1/
#         ├─ d41840771abef0b86af15fdf498e223d297362
#         ├─ fccfaa9e4f7c63a425642d67194d573fbef35e
#         ├─ e231fab74457015881c2cee35d7787fcee26e1
#       ├─ cd/
#         ├─ 83ed723e104086a1a5a16e49a5b3722343dc6f
#         ├─ 4f3bcea975b6d07b829af44d888f22c4458ece
#         ├─ 84dca0562026e132aa982c489a019ca6098bbf
#       ├─ cc/
#         ├─ de39d0b75ce671cdb2d17d7f1eea736211da5c
#         ├─ 812c359f8158f18df7be2732c299217c852315
#       ├─ e6/
#         ├─ 9de29bb2d1d6434b8b29ae775ad8c2e48c5391
#       ├─ f9/
#         ├─ aab7d49355ca3a0efca3f0ea273ac3c037342f
#         ├─ b9d21e056f7dbc83e42fbd5b04c34880ff4733
#       ├─ f0/
#         ├─ 6956c676adc0db108c4e388790c4c85465cbfd
#         ├─ b3e2c335e5c881b34f14e71a267e3113524114
#       ├─ e8/
#         ├─ 4cb64bc1123f1137bed79143f8c1990a69ce94
#         ├─ 4db619d89ad56d03fa0a1473031ab4226e3b68
#         ├─ 64063be8bcb6c07eccf29f71cb1f5c1d007fd3
#       ├─ fa/
#         ├─ 63000611dbc836ff1c7dfaba29cbe5ff2ed16c
#         ├─ 7c7631f22d6e4756a7d7a03fdd0503450116f5
#         ├─ 332300cab035a6d0e691a5c232307ada96637d
#         ├─ 6a187359bf4eea7530becd50b5d81006ef5954
#         ├─ c93b0659478337df8c8b35ebb84ff085e7280e
#       ├─ ff/
#         ├─ b5c155ac5a0286dc1b11c68f54efb0af5b533f
#         ├─ 3e29207c50aae520898938d71058ced7da87ec
#         ├─ 2a6d074b57d7405b4c94cebff5619cf4d0d6e1
#       ├─ c5/
#         ├─ b201010a803f11dc67dac210576da8a0ee7a7d
#       ├─ c2/
#         ├─ bfb5b78e90bb57b41a805ca856903d388a1906
#       ├─ f6/
#         ├─ 225dbaa6c1bc64272c3cd2d0c6bdbb1cb348a8
#       ├─ e9/
#         ├─ d8603ca2d9a51e6cb4a453922678494ede8639
#       ├─ e7/
#         ├─ d44de071998cf4d3c052ee91a2babdb6fe1b7a
#         ├─ 66c8b5fdf3fff409f767134033d1ccdf3baaeb
#       ├─ cb/
#         ├─ b5737538f35a67285f6b9d241e06bac4b75b38
#         ├─ 678b71c8873483409be41c19c93a5f12a81c1f
#         ├─ 305e0ab3693d1d8829bc18289c19946dc94da0
#         ├─ 330170e5838e685d85ab7c6a02c2772dfb402b
#         ├─ 94deba938ea27c63f7f5702d287446004e7528
#       ├─ f8/
#         ├─ 60688630b9aab9e45652079dc5a6a0a27b71d9
#       ├─ ce/
#         ├─ a0b0051988cac57bd0d57703ed42b0ce5d0c07
#         ├─ 776a4f70d53242f83a51c8d788048a7c181b5e
#       ├─ e0/
#         ├─ 808b7eb1e31e0950a97f8f327a9f887852b666
#         ├─ 686aa85af171b16cf86767de413b1348bd78bb
#       ├─ 46/
#         ├─ f3768b573e940a97933bfd5a5dbdca621ab094
#       ├─ 2c/
#         ├─ 8e552679b5cfc8614bd11212db5ebe52777255
#       ├─ 79/
#         ├─ 7b295fff25fd1839b4fde0c84b6791dab17fcf
#         ├─ 5da1d0b1915fd2f67ad14bbee15cbbe17f99d9
#       ├─ 2d/
#         ├─ 627a6f941d634685870bbf7e96f91eed800bdb
#         ├─ 520c394e056b13ea92bd535ad7f73f2f4bffd9
#       ├─ 41/
#         ├─ f1582741d4da891f0e4d73a45727e1b9be1d53
#       ├─ 1b/
#         ├─ 577e93c6e0786d93c0766944f0d4a277e525d3
#         ├─ 2cea3a8f82d8a909eb8286bce11297e2fbdcbc
#         ├─ 2a92456740b1c57f710dc84b1d373231fc35ba
#         ├─ bbb575c78feb0170ba8527b6f79e61e104c674
#         ├─ 4f00018d00a0cb30f60cbca1a4bdca2ea12e05
#       ├─ 77/
#         ├─ f231a27fe2d769d7170841d763d2edcaf61d32
#       ├─ 84/
#         ├─ dadafae0e3febf7c2f744e68514c5ef5bec013
#       ├─ 4a/
#         ├─ 22f197d45e2682cae4014890e5ec158774d734
#         ├─ dc37e2ef745cf85af64f8c9634fd76ef8b2159
#       ├─ 23/
#         ├─ 433466f7e5041d5f16a9e99ca26181f5edbbc5
#         ├─ 3b31dcd0adfcb1616e0c50e5605c0b0ce53671
#       ├─ 15/
#         ├─ 0a2994cf5e7764e8c3848c1d733d812ac14a36
#         ├─ 118bdf4bcf7b4f27fe2a3c63e3989fd13d4b9d
#         ├─ e3c77bfda9344dc35c6369cc45afd3cdf1c017
#       ├─ 12/
#         ├─ b338fbf1871cdece4bcab9580bd2f308af0349
#         ├─ 1c67f08db84983c98bbdd6d1ac796d04c58589
#         ├─ 123d29c2cd1e59dfd1603a3b4c68e3c06d29d1
#         ├─ 687d5fab141e7914be1d24fe1758fd2516d2c1
#         ├─ 758969691b9f9467c4a11c293db2147f4f1af2
#       ├─ 1d/
#         ├─ af20cf302f69da07b18620d7a37a694aca6ef8
#         ├─ 6f0b55eccb29892f7940cd7eff69a68136b488
#         ├─ f50226169030dcb5b9d2a23148988a67068f40
#       ├─ 71/
#         ├─ 2c163e8296eb8f79a5406605291210df72b65a
#         ├─ 7dd5bcc6e5d77ecff4f258b50abff3f7b88272
#         ├─ 8fda697d27b68507945bd61d9dbf49376634b8
#       ├─ 76/
#         ├─ 2e65642b4b2b360d7fb4b58d4d9a7921369ca5
#         ├─ f662cc5c3b5666d10bd20cdc1e9122d4a2328e
#       ├─ 1c/
#         ├─ ea6fa0e7f8df1765464e1dac0bb6cb207286a3
#         ├─ 9a040461c791fe24030b028229aac4a951fa54
#         ├─ 1164466040f3b52e5b123c5357f34c488e9aeb
#       ├─ 2e/
#         ├─ e32920b413e8dc931ec39228c1df5284f6e642
#         ├─ 97ec05d8fffbec8eff25ef25c0944c2f729274
#         ├─ c5fac228ad587acf8d64695201c2cbeddb331f
#         ├─ 13be7e1c2ef56a641d030d643a6f7e68095a26
#       ├─ 47/
#         ├─ d27d297a4d81301081a8979c26b70865ce9a3e
#         ├─ cb79c06404ab4bb0a6ddeb7705608ee97b7344
#       ├─ 78/
#         ├─ 711476095e69576be5884b529d6c28deaf4e4c
#         ├─ 9a18c8daca66dd98ef2f0125995d0bac71abb1
#         ├─ 69eaf18a387c947165f3e9bf1c41bfa137b4aa
#       ├─ 8b/
#         ├─ 2730531f667cf58e70400f83b4411a320e8343
#         ├─ ee5cad33529a4a3bb645ca3a2ea363e0594b45
#       ├─ 13/
#         ├─ 9103bd12d5921c452fa7a19b2efeb770a3f38d
#       ├─ 7f/
#         ├─ 45626bcae4e7a824d78cbc50ae5d01dbb6bdac
#         ├─ 7d1b24133f83c68beb0e2deeedf8b8c96e2dc2
#       ├─ 7a/
#         ├─ f6b72c2997bc5370c475d9cb8d8970304bddfe
#       ├─ 22/
#         ├─ 2bdaf684fe84ef5843f8f476d493c90c487292
#       ├─ 25/
#         ├─ efa44a374c30fd47fef86aa1a484cf94ec6743
#     ├─ info/
#       ├─ exclude
#     ├─ logs/
#       ├─ HEAD
#       ├─ refs/
#         ├─ heads/
#           ├─ main
#         ├─ remotes/
#           ├─ origin/
#             ├─ HEAD
#             ├─ main
#     ├─ hooks/
#       ├─ commit-msg.sample
#       ├─ post-commit
#       ├─ pre-rebase.sample
#       ├─ pre-commit.sample
#       ├─ post-checkout
#       ├─ applypatch-msg.sample
#       ├─ fsmonitor-watchman.sample
#       ├─ pre-receive.sample
#       ├─ prepare-commit-msg.sample
#       ├─ post-update.sample
#       ├─ pre-merge-commit.sample
#       ├─ pre-applypatch.sample
#       ├─ pre-push
#       ├─ post-merge
#       ├─ pre-push.sample
#       ├─ update.sample
#       ├─ push-to-checkout.sample
#     ├─ refs/
#       ├─ heads/
#         ├─ main
#       ├─ tags/
#       ├─ remotes/
#         ├─ origin/
#           ├─ HEAD
#           ├─ main
#     ├─ lfs/
#       ├─ cache/
#         ├─ locks/
#           ├─ refs/
#             ├─ heads/
#               ├─ main/
#                 ├─ verifiable
#       ├─ objects/
#         ├─ 58/
#           ├─ 1f/
#             ├─ 581f7651c0aa6ed261cf892a3f47105d959dd00b1a1a960acff0b6aa47e75b0d
#         ├─ 02/
#           ├─ de/
#             ├─ 02de69d821f7a34fb68d3aa45f17bce28690a3a97c23b145720f2a3e9568dc10
#         ├─ d0/
#           ├─ 2c/
#             ├─ d02c1f7d535c0cf9881456f2bbfa623c831f9bfa38e085dc435cf80f677c9b40
#           ├─ 8c/
#             ├─ d08cb34336fa5b3599b6ff03c07a57fa11b5cbbdeed790aee35ac4b0d05aedfc
#         ├─ d8/
#           ├─ 3a/
#             ├─ d83a450dd83426c76a7a97886902da470323135e010989920997337665fd3bdf
#         ├─ fc/
#           ├─ 4e/
#             ├─ fc4e15db1ca15d06d48b1692d0368f47d3c4ff31aaef0257bec3d875b8844856
#         ├─ e4/
#           ├─ 2e/
#             ├─ e42e095876216ff09fed8a9d5271203a2ae45b7db488a76fe0e0f9cdc75b8f11
#         ├─ ec/
#           ├─ b2/
#             ├─ ecb2a8b88f6c8055c086f97824dd07a3f02c6fc0da55213d03c0aff4266e7896
#         ├─ 4b/
#           ├─ b3/
#             ├─ 4bb39db67b67346f21ca91c2a80be6b83983e230b567f3cb3a61d6e3d2b4fbbf
#         ├─ 11/
#           ├─ ef/
#             ├─ 11ef4ca5132fa1d0be4528dd4255dd6b2b25faae4e9c2f8ede4c825e50c3109d
#         ├─ 17/
#           ├─ f4/
#             ├─ 17f4697946a05647143fd4b85808f090a7b5594626ed6f2d0a440a52a2197a69
#         ├─ 8a/
#           ├─ 7c/
#             ├─ 8a7c2c0a0e97ed8f8c29aac1ad46c3cb0ec276ac1f98ca603b3a4725ca50b013
#         ├─ 21/
#           ├─ ac/
#             ├─ 21ac0f6f65ed4ec6dce79c1311ec07be75cf3bb275902a89247c082a5bfc155c
#         ├─ 86/
#           ├─ c9/
#             ├─ 86c9d1a0b0d2710cbdbc86979c6d68d363239752661fc79336d2b77947005603
#         ├─ 2f/
#           ├─ d0/
#             ├─ 2fd0fa75a28e3ddfa5f37330e48c1a977db298c578757d12a3608f8d10baf492
#         ├─ 88/
#           ├─ 59/
#             ├─ 88597807120007325dcef207b57ca6bc84e21bb8fbfdafa78ab82a3694bf6562
#         ├─ 31/
#           ├─ 71/
#             ├─ 31713b56c900657fe3b2c93538faedeebe0d78de7c1029c36f471e49eef24790
#         ├─ 91/
#           ├─ 8f/
#             ├─ 918fa1518f4a238a726f09efc128588bdfc6a90a17adc0fc9dd0e9d53067a358
#         ├─ 53/
#           ├─ ec/
#             ├─ 53ec5606f97a6210ddd5348887dd82f11c0a24e799715bfb9c6a4c2dc27260f9
#           ├─ dc/
#             ├─ 53dcd144984e593145f1803b9e348018ffe8c7fb5abb343342d38a770c9d26b0
#         ├─ 3f/
#           ├─ a0/
#             ├─ 3fa0ab2add7e16177785c338975e28d0fc686ba863e3cd914c454477e813534a
#         ├─ 30/
#           ├─ ef/
#             ├─ 30effae48c6cd8bc8e30ee46ff7b7fd68ba47a567b0127f1a3bfbdbe5e9e08d2
#         ├─ 08/
#           ├─ 39/
#             ├─ 0839594480cb5956747d25320ff8eb9e317f09caaa8c7e67ac393d83664316be
#         ├─ 6d/
#           ├─ b5/
#             ├─ 6db553ce367a1cda5e24b77bf821ceebf7fba2f9f0ebe0b8f94f566b988fe007
#         ├─ d3/
#           ├─ 25/
#             ├─ d32542d4e3d752439e8d83466d3d9d70f77018bdb435db947aeede5416389404
#         ├─ ba/
#           ├─ 6c/
#             ├─ ba6c28a7443d502f443039a2e23eed5280867cd405726f15fd4ac1c717e07a6a
#         ├─ a9/
#           ├─ 76/
#             ├─ a9760ed57e7a54fa5a2b5cc9e64bde75418c6725a9be1c51e5ed31d92b70ad21
#         ├─ de/
#           ├─ 7a/
#             ├─ de7ac389d0f67f14d6e395ec0c9911cba7f57af9310e8d7002bbee126beaec30
#         ├─ a1/
#           ├─ 38/
#             ├─ a138e88d02d835ee1afe87039685a27b0494ada67e6a8e48815304a979d2131b
#         ├─ cc/
#           ├─ df/
#             ├─ ccdf6732da76cf3ed07345429dc09ecfacc59aa48b27b28e7cb9d31ccf01f3ae
#           ├─ db/
#             ├─ ccdbd767b607ce63eedcea88fc9341d219ecd00fc4cffcadb74bfbf53948b917
#         ├─ f9/
#           ├─ ce/
#             ├─ f9ceacf291749c68f09539dea08f6092733790f8ed2789fe08b5e8d1c70c86a7
#         ├─ 41/
#           ├─ 27/
#             ├─ 4127267f178169ff2508008ff4de536a1e83740014dcb6efd5c2e78df3ffeaed
#         ├─ 70/
#           ├─ 6d/
#             ├─ 706d3443af6e720d725fb2b7c30673ed608552f53ce64be03959e33ee16b84c7
#         ├─ 15/
#           ├─ e2/
#             ├─ 15e281f95cadd75a781326a933632f7701dd6fadfa317142faa0e5d7bbe0b312
#       ├─ tmp/
#   ├─ data/
#     ├─ .DS_Store
#     ├─ scrapper/
#       ├─ mediastack/
#         ├─ .gitignore
#         ├─ scrapping_mediastack.py
#     ├─ main_data/
#       ├─ .DS_Store
#       ├─ main_dataset.xlsx
#       ├─ main_dataset.json
#       ├─ probability/
#         ├─ .DS_Store
#         ├─ unlabeled_probability.json
#       ├─ finetuning/
#         ├─ .DS_Store
#         ├─ unlabeled_finetuning.xlsx
#         ├─ unlabeled_finetuning.json
#     ├─ add/
#       ├─ duplicate_detection.xlsx
#       ├─ non_english_removed.xlsx
#     ├─ raw/
#       ├─ raw.json
#       ├─ raw.xlsx
#   ├─ outputs/
#     ├─ Decay vs Exponential.png
#     ├─ Training&Validation Loss and F1 Macro.png
#     ├─ Training and Validation Loss.png
#   ├─ notebooks/
#     ├─ eda_raw.ipynb
#     ├─ datasplit.ipynb
#     ├─ datapreprocess.ipynb
#     ├─ general.ipynb
